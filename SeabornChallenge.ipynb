# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('DataFiles/insurance.csv')

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
sns.relplot(data=df, x='bmi', y='charges', col='sex',)

# %%
sns.relplot(data=df, x='bmi', y='charges', kind='scatter', size='region')

# %%
df['smoker_ind']=df['smoker'].map({'yes':'smoker','no':'non-smoker'})

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges  smoker_ind
# 0   19  female  27.900         0    yes  southwest  16884.92400      smoker
# 1   18    male  33.770         1     no  southeast   1725.55230  non-smoker
# 2   28    male  33.000         3     no  southeast   4449.46200  non-smoker
# 3   33    male  22.705         0     no  northwest  21984.47061  non-smoker
# 4   32    male  28.880         0     no  northwest   3866.85520  non-smoker

# %%
sns.relplot(data=df, x='bmi', y='charges', col='sex', hue='smoker_ind', kind='scatter', size='region', alpha=0.5)

# %%
sns.pairplot (df, hue='smoker_ind')

# %%
sns.pairplot (df, hue='sex')

# %%
sns.relplot(data=df, x='charges', y='age', kind='scatter', hue='sex')

# %%
sns.catplot(data=df, x='age', y='bmi', kind='box')

# %%
sns.catplot(data=df, x='age', y='bmi', kind='box')

# %%
sns.lineplot(data=df, x='age', y='bmi')
# Out:
# <Axes: xlabel='age', ylabel='bmi'>
