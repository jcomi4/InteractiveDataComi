# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Looking at the options provided, I would like to engage with the "Overlapping Destinies" visual. I find this one very engaging and I am impressed by the amount of data it is able to provide in a 2D, non-interactive visual. I would use this in my career to visualize traffic/interactions between different social media platforms for a specific company or brand. I feel that this visual is specifically great for this as it allows us to track data over time for multiple variables, essentally tracking 3 variables at once (type of brand, traffic, and time). Many of these visuals can only track two types of data. Not only does it allow us to track multiple data types, but it also allows us to compare the different types of brand with each other. For example, not only could we see that Instagram traffic rises during noon but falls drastically after 4:00, but we could also compare how these rises and falls coorespond with other platforms like Facebook. We can then make inferences based on that data, which would be very useful in a buisness sense.

# %%
myDf = pd.read_csv('DataFiles/cces_example_data.csv')

# %%
myDf
# Out:
#      pew_religimp  pew_churatd  sex  educ  nonwhite  age  faminc_new  pid3  \
# 0               2            6    2     2         1   56           6     1
# 1               2            4    2     5         1   53          13     1
# 2               1            2    1     2         1   69          10     2
# 3               2            3    1     6         1   76          97     1
# 4               4            5    2     6         1   83           4     1
# ..            ...          ...  ...   ...       ...  ...         ...   ...
# 654             1            5    2     2         2   30           4     1
# 655             2            2    1     4         1   19          97     1
# 656             4            6    1     3         1   20           7     1
# 657             2            2    1     3         1   23           5     2
# 658             2            2    1     3         1   23           5     2
#
# ...

# %%
fig1, ax1 = plt.subplots(2)
ax1[0].set_title('Age Histogram')
ax1[1].set_title('Political Identity')
plt.show()

# %%
e_count = myDf.groupby('Evaluation').count()['caseid']
e_count.index
# Out:
# Index([0, 1, 2, 3], dtype='int64', name='Evaluation')

# %%
e_count.values
# Out:
# array([365,  48, 202,  44])

# %%
fig2, ax2 = plt.subplots()
ax2.set_xlabel('Index')
ax2.set_ylabel('Evaluation')
ax2.bar(x = e_count.index, height = e_count.values)
plt.show()

# %%
fig3, ax3 = plt.subplots()
ax3.set_xlabel('ConMediaUse')
ax3.set_ylabel('ImmiPhobia')
ax3.scatter(myDf["ConMediaUse"], myDf['ImmiPhobia'])
plt.show()

# %% [markdown]
# I think that this visualization does a poor job in explaining what exactly is trying to be conveyed by the message, and furthermore, doesn't really acomplish it's goal as a graph. I think it fails at this because it is far too cluttered and could have used a much wider range of numbers to spread the data out. Also, as stated in section 5.4, "Scatterplots represent the archetypical visualization when we want to show one quantitative variable relative to another". I think that this doesn't acomplish this because there are very few dots that are not immidietly relative to other dots. This tells us very little about the data. I would increase the ammounts on the X and Y axis to give the reader context, and I would also consider using a different type of graph. Truth be told, I am not sure exactly what kind of data is being measured here, so it is difficult to say what I would do to improve, but those are a few of my starting points.
