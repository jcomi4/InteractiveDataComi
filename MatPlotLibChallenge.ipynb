# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Markdown cell question 1 - answer here

# %%
myDf = pd.read_csv('DataFiles/cces_example_data.csv')

# %%
myDf
# Out:
#      pew_religimp  pew_churatd  sex  educ  nonwhite  age  faminc_new  pid3  \
# 0               2            6    2     2         1   56           6     1
# 1               2            4    2     5         1   53          13     1
# 2               1            2    1     2         1   69          10     2
# 3               2            3    1     6         1   76          97     1
# 4               4            5    2     6         1   83           4     1
# ..            ...          ...  ...   ...       ...  ...         ...   ...
# 654             1            5    2     2         2   30           4     1
# 655             2            2    1     4         1   19          97     1
# 656             4            6    1     3         1   20           7     1
# 657             2            2    1     3         1   23           5     2
# 658             2            2    1     3         1   23           5     2
#
# ...

# %%
fig1, ax1 = plt.subplots()
ax1.set_xlabel('Y-Axis')
ax1.set_ylabel('X-Axis')
ax.plot(myDf['Evaluation'], myDf['sex'])
plt.show()

# %%
fig1, ax1 = plt.subplots()
ax1.set_xlabel('Index')
ax1.set_ylabel('Evaluation')
ax1.bar(myDf.index, myDf['Evaluation'])
plt.show()

# %%
fig1, ax1 = plt.subplots()
ax1.set_xlabel('ConMediaUse')
ax1.set_ylabel('ImmiPhobia')
ax1.scatter(myDf["ConMediaUse"], myDf['ImmiPhobia'])
plt.show()

# %% [markdown]
# Markdown cell question 2 - answer here
